# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
import scipy.stats
from matplotlib import gridspec
import matplotlib.lines as mlines
from scipy.stats import chi2

plt.rcParams["font.family"] = "serif"
label_font_size= 28
tick_font_size= 15
text_font_size= 22

def getContour(x,y,z,val):
    N=1000

    levels = [val]

    #xi = np.linspace(x.min(), x.max(), N)
    #yi = np.linspace(y.min(), y.max(), N)
    xi = np.logspace(np.log(x.min()), np.log(x.max()), N)
    yi = np.logspace(np.log(y.min()), np.log(y.max()), N)
    zi = scipy.interpolate.griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')

    cs = plt.contour(xi,yi,zi,levels, colors='black')
    
    p = cs.collections[0].get_paths()[0]
    v = p.vertices
    return v

# %% [markdown]
# # Oscillation plots

# %%
fig= plt.figure( dpi=150,frameon=False,facecolor='none')
ax = fig.add_subplot(111)

x = np.linspace(0,1000,100)

plt.xlim(0,1000)
plt.ylim(0,17)

y = 10000* chi2.pdf(x,37,-800,30)
#ydis = 8000* chi2.pdf(x,40,-900,30) + np.sin(x/20)/(x/200+1)
a = .25
b = 800
ydis = y * (1 - 4*np.power(a,2)*(1-np.power(a,2))*np.power(np.sin(b/(x+1)),2)) *.9


c = 'black'

plt.plot(x,y,color=c,linewidth=2.5,label=r'$\nu_\mu$ No Osc')
plt.plot(x,ydis,'--',color=c,linewidth=2.5,label=r'$\nu_\mu$ Dis')

ax.set_xlabel(r'$\nu_\mu$ Energy',fontsize=20,color=c)
ax.set_ylabel('Events',fontsize=20,color=c)


plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(c)
ax.spines['left'].set_color(c)

ax.tick_params(axis='both', which='both', length=0)

plt.fill_between(x, y, ydis,hatch='.',facecolor='none',edgecolor=c,linewidth=0.0)

plt.legend(frameon=False,fontsize=15)
fig.savefig('numu.png', transparent=True)

# %%
fig= plt.figure( dpi=150,frameon=False,facecolor='none')
ax = fig.add_subplot(111)

x = np.linspace(0,1000,100)

plt.xlim(0,1000)
plt.ylim(0,17)

y = 10000* chi2.pdf(x,37,-800,30)
#ydis = 8000* chi2.pdf(x,40,-900,30) + np.sin(x/20)/(x/200+1)
a = .25
b = 800
ydis = y * (1 - 4*np.power(a,2)*(1-np.power(a,2))*np.power(np.sin(b/(x+1)),2)) *.9


c = 'black'

plt.plot(x,y-ydis,'--',color=c,linewidth=2.5,label=r'$\nu_\mu$ Dis')



ax.set_xlabel(r'$\nu_\mu$ Energy',fontsize=20,color=c)
ax.set_ylabel('Events',fontsize=20,color=c)


plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(c)
ax.spines['left'].set_color(c)

ax.tick_params(axis='both', which='both', length=0)

plt.fill_between(x, y-ydis,np.zeros(len(x)),hatch='.',facecolor='none',edgecolor=c,linewidth=0.0)

plt.legend(frameon=False,fontsize=15)
fig.savefig('numu.png', transparent=True)

# %%
fig= plt.figure( dpi=150,frameon=False,facecolor='none')
ax = fig.add_subplot(111)

x = np.linspace(0,1000,100)

plt.xlim(0,1000)
plt.ylim(0,17)

y = 10000* chi2.pdf(x,37,-800,30)
#ydis = 8000* chi2.pdf(x,40,-900,30) + np.sin(x/20)/(x/200+1)
a = .25
b = 800
ydis = y * (1 - 4*np.power(a,2)*(1-np.power(a,2))*np.power(np.sin(b/(x+1)),2)) *.9


c = 'black'

plt.plot(x,y,color=c,linewidth=2.5,label=r'$\nu_\mu$ No Osc')

ax.set_xlabel(r'$\nu_\mu$ Energy',fontsize=20,color=c)
ax.set_ylabel('Events',fontsize=20,color=c)


plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(c)
ax.spines['left'].set_color(c)

ax.tick_params(axis='both', which='both', length=0)


plt.legend(frameon=False,fontsize=15)
fig.savefig('numu.png', transparent=True)

# %%
fig= plt.figure( dpi=150,frameon=False,edgecolor='red')
ax = fig.add_subplot(111)

x = np.linspace(0,1000,100)

plt.xlim(0,1000)
plt.ylim(0,17)

y = 3500* chi2.pdf(x,24,-420,30)
#ydis = 2300* chi2.pdf(x,25,-440,30) + np.sin(x/30)/(x/100+1)
#yapp = 4500* chi2.pdf(x,22,-360,30) + np.sin(x/20)/(x/50+1)

a = .25
b = 700
c = .35
ydis = y * (1 - 4*np.power(a,2)*(1-np.power(a,2))*np.power(np.sin(b/(x+1)),2)) *.9
yapp = (y + y * 4*np.power(a,2)*np.power(c,2)*np.power(np.sin(b/(x+1)),2)) * 1.3

c = 'black'

plt.plot(x,y,color=c,linewidth=2.5,label=r'$\nu_e$ No Osc')
plt.plot(x,ydis,'--',color=c,linewidth=2.5,label=r'$\nu_e$ Dis')
plt.plot(x,yapp,':',color=c,linewidth=2.5,label=r'$\nu_e$ App')

ax.set_xlabel(r'$\nu_e$ Energy',fontsize=20,color=c)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(c)
ax.spines['left'].set_visible(False)


ax.tick_params(axis='both', which='both', length=0)


plt.fill_between(x, y, ydis,hatch='.',facecolor='none',edgecolor=c,linewidth=0.0)
plt.fill_between(x, yapp, y,hatch='o',facecolor='none',edgecolor=c,linewidth=0.0)
fig.savefig('nue.png', transparent=True)


plt.legend(frameon=False,fontsize=15)

# %% [markdown]
# # Pretty cov matrices

# %%
f = TFile('matrices/DL.SBNcovar.root')
a = f.Get('full_correlation_DL')

m = matrix(a)

# %%
f=plt.figure(dpi=250)
ax=plt.subplot(111)

plt.imshow(m)
plt.axvline(x=29.5,color='red',linewidth=4)
plt.axhline(y=29.5,color='red',linewidth=4)

plt.plot(np.array((-.5,29.5)),np.array((9.5,9.5)),'--',color='red',linewidth=2.5,)
plt.plot(np.array((9.5,9.5)),np.array((-.5,29.5)),'--',color='red',linewidth=2.5)

plt.plot(np.array((-.5,29.5)),np.array((4.5,4.5)),':',color='red')
plt.plot(np.array((4.5,4.5)),np.array((-.5,29.5)),':',color='red')

plt.plot(np.array((-.5,29.5)),np.array((19.5,19.5)),':',color='red')
plt.plot(np.array((19.5,19.5)),np.array((-.5,29.5)),':',color='red')

plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
ax.tick_params(axis='both', which='both', length=0)

plt.colorbar()

# %%
f = TFile('matrices/SBNfit_covariance_plots_DL.root')
a = f.Get('collapsed_correlation')

m = matrix(a)

# %%
f=plt.figure(dpi=250)
ax=plt.subplot(111)

plt.imshow(m)
plt.axvline(x=14.5,color='red',linewidth=4)
plt.axhline(y=14.5,color='red',linewidth=4)

plt.plot(np.array((-.5,29.5)),np.array((4.5,4.5)),'--',color='red',linewidth=2.5,)
plt.plot(np.array((4.5,4.5)),np.array((-.5,29.5)),'--',color='red',linewidth=2.5)

plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
ax.tick_params(axis='both', which='both', length=0)

# %% [markdown]
# # Sensitivities

# %%
str_date = 'October 11, 2018'
str_tag = 'DL Review'

cLSNDb = 'yellowgreen'
cLSND = 'olivedrab'

cGIUNTI = 'darkturquoise'
cGIUNTIb = 'aqua'

c_nueapp = 'coral'
c_nueapp_stats = 'orangered'

c_c_nodis = 'pink'
c_c_nodis_stats = 'darkmagenta'

c_c = 'tomato'
c_c_stats = 'maroon'

c_past = 'lightsteelblue'
c_past_stats = 'steelblue'


c_reg = 'plum'
c_doubleEff = 'mediumorchid'
c_best = 'rebeccapurple'

sample = 'November 2018'
sampleloc = 'chi2_November2018/'

# %%
# Load my stuff
dl_nueapp=np.genfromtxt("posterstuff/ue5aspoint12/chi2_nueapp.dat")
cont_dl_nueapp = getContour(dl_nueapp[:,4],dl_nueapp[:,1],dl_nueapp[:,5],1.28)

dl_combined=np.genfromtxt("posterstuff/ue5aspoint12/chi2_combined.dat")
cont_dl_combined = getContour(dl_combined[:,4],dl_combined[:,1],dl_combined[:,5],1.28)

dl_nueapp_numudis=np.genfromtxt("posterstuff/ue5aspoint12/chi2_nueapp_numudis.dat")
cont_dl_nueapp_numudis = getContour(dl_nueapp_numudis[:,4],dl_nueapp_numudis[:,1],dl_nueapp_numudis[:,5],1.28)

# %%
#Create a new subplot from a grid of 1x1
f=plt.figure(figsize=(10,10), dpi=150)

ax=plt.subplot(111)
ax.set_xscale("log", nonposx='clip')
ax.set_yscale("log", nonposy='clip')

ax.set_xlabel(r'$\sin^2 2 \theta_{\mu e}$',fontsize=label_font_size)
ax.set_ylabel(r'$\Delta m_{41}^2$  [eV$^2$]',fontsize=label_font_size)

ln1, = plt.plot(cont_dl_nueapp[:,0], cont_dl_nueapp[:,1],  color='darkred',linewidth=3, linestyle="-")
ln2, = plt.plot(cont_dl_nueapp_numudis[:,0], cont_dl_nueapp_numudis[:,1],  color='tomato',linewidth=3, linestyle="-")
ln3, = plt.plot(cont_dl_combined[:,0], cont_dl_combined[:,1],  color='pink',linewidth=3, linestyle="-")

#plt.annotate('13E20 POT\nNue Sample Only\nAppearance Only\n'+sample,xy=(0.05, .21), xycoords='axes fraction',fontsize=text_font_size-2)
ax.legend((ln1, ln2, ln3), (r'$\nu_e$ App 90% CL', r'$\nu_e$ App + $\nu_\mu$ Dis 90%CL',r'$\nu_e$ App/Dis + $\nu_\mu$ Dis 90%CL'),loc='upper left',bbox_to_anchor=(0, 0.3),fontsize=20,frameon=False)

# Set axis limits and 
plt.xlim(1e-5,1)
plt.ylim(0.01,100)

ax.tick_params('both',labelsize=tick_font_size)
ax.tick_params('both',length=7, width=1, which='minor' )
ax.tick_params('both',length=13, width=1.7, which='major' )


# Show result on screen
plt.show()
f.savefig("dl_sens.pdf", bbox_inches='tight')
